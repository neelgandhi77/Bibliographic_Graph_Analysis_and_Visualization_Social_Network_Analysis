# %% [markdown]
# #ASSIGNMENT 3 (Date of submission: 14/06/2023)
# #A) Plot bibliographic graph(or its subgraph) for a hetrogenous network and visualize it

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Load the Medical Tourism DataSet.csv dataset using pandas
df = pd.read_csv('/content/Medical Tourism DataSet.csv')
df
# Out:
#                                          Authors  \
# 0                                     Connell J.
# 1                     Bookman M.Z., Bookman K.R.
# 2                                     Connell J.
# 3                      Mueller H., Kaufmann E.L.
# 4     Horowitz M.D., Rosensweig J.A., Jones C.A.
# ...                                          ...
# 1530                                  Witts L.J.
# 1531                                  Witts L.J.
# 1532                                  STANTON M.
# 1533                                    PAABY H.
# 1534                                  Blake R.C.
#
#                               Author(s) ID  \
# 0                             56227359000;
# 1                  7005651465;57193532861;
# 2                             56227359000;
# 3                  56127515200;7005400051;
# 4     57210536016;23005952900;57183388900;
# ...                                    ...
# 1530                           6603406891;
# 1531                           6603406891;
# 1532                          56679295300;
# 1533                          57189141639;
# 1534                          56877689300;
#
#                                                   Title  Year  \
# 0       Medical tourism: Sea, sun, sand and ... surgery  2006
# 1               Medical tourism in developing countries  2007
# 2     Contemporary medical tourism: Conceptualisatio...  2013
# 3     Wellness tourism: Market analysis of a special...  2001
# 4     Medical tourism: Globalization of the healthca...  2007
# ...                                                 ...   ...
# 1530                      REFLECTIONS ON MEDICAL TRAVEL  1957
# 1531                      REFLECTIONS ON MEDICAL TRAVEL  1957
# 1532  The cafeteria comes to the patients; mobilteri...  1955
# 1533  Incidence of thromboembolism in surgical patie...  1955
# 1534                  Medical tourists in great britain  1952
#
#                                      Source title Volume Issue Art. No.  \
# 0                              Tourism Management     27     6      NaN
# 1         Medical Tourism in Developing Countries    NaN   NaN      NaN
# 2                              Tourism Management     34   NaN      NaN
# 3                   Journal of Vacation Marketing      7     1      NaN
# 4             MedGenMed Medscape General Medicine      9     4       33
# ...                                           ...    ...   ...      ...
# 1530                                   The Lancet    269  6983      NaN
# 1531                                   The Lancet    269  6982      NaN
# 1532                              Modern hospital     84     5      NaN
# 1533                      Danish medical bulletin      2     3      NaN
# 1534  Journal of the American Medical Association    148    17      NaN
#
#      Page start Page end  ...                          ISBN  CODEN  \
# 0          1093     1100  ...                           NaN    NaN
# 1             1      245  ...  9780230605657; 9780230600058    NaN
# 2             1       13  ...                           NaN    NaN
# 3             5       17  ...                           NaN    NaN
# 4           NaN      NaN  ...                           NaN  MMGMC
# ...         ...      ...  ...                           ...    ...
# 1530       1343     1345  ...                           NaN  LANCA
# 1531       1291     1292  ...                           NaN  LANCA
# 1532        114      120  ...                           NaN    NaN
# 1533         82       84  ...                           NaN    NaN
# 1534       1527      NaN  ...                           NaN    NaN
#
#        PubMed ID Language of Original Document  \
# 0            NaN                       English
# 1            NaN                       English
# 2            NaN                       English
# 3            NaN                       English
# 4     18311383.0                       English
# ...          ...                           ...
# 1530  13440047.0                       English
# 1531  13440029.0                       English
# 1532  14370038.0                       English
# 1533  14379742.0                       English
# 1534         NaN                       English
#
#                 Abbreviated Source Title Document Type Publication Stage  \
# 0                          Tour. Manage.       Article             Final
# 1     Med. Tourism in Developing Ctries.          Book             Final
# 2                          Tour. Manage.        Review             Final
# 3                        J. Vacat. Mark.       Article             Final
# 4           Medgenmed Medscape Gen. Med.       Article             Final
# ...                                  ...           ...               ...
# 1530                              Lancet       Article             Final
# 1531                              Lancet       Article             Final
# 1532                            Mod Hosp       Article             Final
# 1533                        Dan Med Bull       Article             Final
# 1534                                JAMA        Letter             Final
#
#      Access Type  Source                 EID
# 0            NaN  Scopus  2-s2.0-33746326777
# 1            NaN  Scopus  2-s2.0-85014664334
# 2            NaN  Scopus  2-s2.0-84867139510
# 3            NaN  Scopus  2-s2.0-84899155038
# 4            NaN  Scopus  2-s2.0-36249026987
# ...          ...     ...                 ...
# 1530         NaN  Scopus  2-s2.0-49749173739
# 1531         NaN  Scopus  2-s2.0-49749159158
# 1532         NaN  Scopus  2-s2.0-77049205104
# 1533         NaN  Scopus  2-s2.0-77049201351
# 1534         NaN  Scopus  2-s2.0-84942562563
#
# [1535 rows x 46 columns]

# %%
# Select specific columns
selected_columns = ['Authors', 'Title', 'Year', 'Issue','Volume', 'Cited by', 'Affiliations', 'Authors with affiliations', 'Publisher','References',
       'Correspondence Address','ISSN','Language of Original Document','Document Type', 'Publication Stage', 'Source', 'EID']
df = df[selected_columns]
df
# Out:
#                                          Authors  \
# 0                                     Connell J.
# 1                     Bookman M.Z., Bookman K.R.
# 2                                     Connell J.
# 3                      Mueller H., Kaufmann E.L.
# 4     Horowitz M.D., Rosensweig J.A., Jones C.A.
# ...                                          ...
# 1530                                  Witts L.J.
# 1531                                  Witts L.J.
# 1532                                  STANTON M.
# 1533                                    PAABY H.
# 1534                                  Blake R.C.
#
#                                                   Title  Year Issue Volume  \
# 0       Medical tourism: Sea, sun, sand and ... surgery  2006     6     27
# 1               Medical tourism in developing countries  2007   NaN    NaN
# 2     Contemporary medical tourism: Conceptualisatio...  2013   NaN     34
# 3     Wellness tourism: Market analysis of a special...  2001     1      7
# 4     Medical tourism: Globalization of the healthca...  2007     4      9
# ...                                                 ...   ...   ...    ...
# 1530                      REFLECTIONS ON MEDICAL TRAVEL  1957  6983    269
# 1531                      REFLECTIONS ON MEDICAL TRAVEL  1957  6982    269
# 1532  The cafeteria comes to the patients; mobilteri...  1955     5     84
# 1533  Incidence of thromboembolism in surgical patie...  1955     3      2
# 1534                  Medical tourists in great britain  1952    17    148
#
#       Cited by                                       Affiliations  \
# 0        489.0  School of Geosciences, University of Sydney, N...
# 1        257.0  St. Joseph’s University, Philadelphia, United ...
# 2        230.0  School of Geosciences, University of Sydney, N...
# 3        202.0  Research Institute for Leisure and Tourism, Un...
# 4        190.0  Global Perspectives Program, Goizueta Business...
# ...        ...                                                ...
# 1530       NaN                 UNIVERSITY, OXFORD, United Kingdom
# 1531       NaN                 UNIVERSITY, OXFORD, United Kingdom
# 1532       NaN                                                NaN
# 1533       NaN                                                NaN
# 1534       NaN  London Hospital Medical Society, Turner St., L...
#
#                               Authors with affiliations           Publisher  \
# 0     Connell, J., School of Geosciences, University...                 NaN
# 1     Bookman, M.Z., St. Joseph’s University, Philad...  Palgrave Macmillan
# 2     Connell, J., School of Geosciences, University...                 NaN
# 3     Mueller, H., Research Institute for Leisure an...                 NaN
# 4     Horowitz, M.D., Global Perspectives Program, G...                 NaN
# ...                                                 ...                 ...
# 1530    Witts, L.J., UNIVERSITY, OXFORD, United Kingdom                 NaN
# 1531    Witts, L.J., UNIVERSITY, OXFORD, United Kingdom                 NaN
# 1532                                        STANTON, M.                 NaN
# 1533                                          PAABY, H.                 NaN
# 1534  Blake, R.C., London Hospital Medical Society, ...                 NaN
#
#                                              References  \
# 0     Ai-Lien, C., Singapore steps up efforts to woo...
# 1     Yim, C.K.B., (2006) Healthcare Destinations in...
# 2     Ackerman, S., Plastic paradise: transforming b...
# 3     (1999) Wellness-Tourismus in Der Schweiz - Qua...
# 4     Lancaster, J., Surgeries, side trips for medic...
# ...                                                 ...
# 1530                                                NaN
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
#
#                                  Correspondence Address      ISSN  \
# 0     Connell, J.; School of Geosciences, University...  02615177
# 1                                                   NaN       NaN
# 2     Connell, J.; School of Geosciences, University...  02615177
# 3                                                   NaN  13567667
# 4     Horowitz, M.D.; Global Perspectives Program, G...  15310132
# ...                                                 ...       ...
# 1530      Witts, L.J.; UNIVERSITY, OXFORDUnited Kingdom  01406736
# 1531      Witts, L.J.; UNIVERSITY, OXFORDUnited Kingdom  01406736
# 1532                                        STANTON, M.  0026783X
# 1533                                          PAABY, H.  09078916
# 1534  Blake, R.C.; London Hospital Medical Society, ...  00029955
#
#      Language of Original Document Document Type Publication Stage  Source  \
# 0                          English       Article             Final  Scopus
# 1                          English          Book             Final  Scopus
# 2                          English        Review             Final  Scopus
# 3                          English       Article             Final  Scopus
# 4                          English       Article             Final  Scopus
# ...                            ...           ...               ...     ...
# 1530                       English       Article             Final  Scopus
# 1531                       English       Article             Final  Scopus
# 1532                       English       Article             Final  Scopus
# 1533                       English       Article             Final  Scopus
# 1534                       English        Letter             Final  Scopus
#
#                      EID
# 0     2-s2.0-33746326777
# 1     2-s2.0-85014664334
# 2     2-s2.0-84867139510
# 3     2-s2.0-84899155038
# 4     2-s2.0-36249026987
# ...                  ...
# 1530  2-s2.0-49749173739
# 1531  2-s2.0-49749159158
# 1532  2-s2.0-77049205104
# 1533  2-s2.0-77049201351
# 1534  2-s2.0-84942562563
#
# [1535 rows x 17 columns]

# %%
# Remove rows with NaN or null values
df.dropna(inplace=True)
df
# Out:
# <ipython-input-7-338c4f99e752>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                                                 Authors  \
# 15         Glinos I.A., Baeten R., Helble M., Maarse H.
# 24                                      García-Altés A.
# 36                               Cormany D., Baloglu S.
# 41                              Abubakar A.M., Ilkan M.
# 43    Nydahl P., Sricharoenchai T., Chandra S., Kund...
# ...                                                 ...
# 998                      Hin C.W., Bohari A.M., Pu L.T.
# 1015                 Sokol T., Hodak L.M., Abramović A.
# 1023                                          McHale J.
# 1034                                          Lang I.G.
# 1043                                      Offermanns G.
#
#                                                   Title  Year Issue Volume  \
# 15          A typology of cross-border patient mobility  2010     6     16
# 24           The development of health tourism services  2005     1     32
# 36    Medical travel facilitator websites: An explor...  2011     4     32
# 41    Impact of online WOM on destination trust and ...  2016     3      5
# 43    Safety of patient mobilization and rehabilitat...  2017     5     14
# ...                                                 ...   ...   ...    ...
# 998   An analysis of competitiveness of medical tour...  2013     6      7
# 1015  Patient mobility directive: One step forward o...  2012  2012      8
# 1023   Health tourism and the UK: Some new developments  2010    14     19
# 1034  Patient mobility in the European Union: pushin...  2009     4     28
# 1043  Patient mobility in Europe [Patientenmobilität...  2007    56     15
#
#       Cited by                                       Affiliations  \
# 15       119.0  Department of Health Organisation, Policy and ...
# 24       101.0  Fund. Inst. de Invest./Serv. Salud, Pere Seraf...
# 36        79.0  University of Nevada, Harrah College of Hotel ...
# 41        74.0  Department of Economics and Business Administr...
# 43        71.0  Nursing Research, University Hospital of Schle...
# ...        ...                                                ...
# 998        1.0  College of Business, Universiti of Utara Malay...
# 1015       1.0  KU Leuven, Institute for Social Law, Belgium; ...
# 1023       1.0  School of Law, University of Birmingham, Unite...
# 1034       1.0  London School of Economics and Political Scien...
# 1043       1.0  Alpen-Adria-Universität Klagenfurt, Fakultät f...
#
#                               Authors with affiliations  \
# 15    Glinos, I.A., Department of Health Organisatio...
# 24    García-Altés, A., Fund. Inst. de Invest./Serv....
# 36    Cormany, D., University of Nevada, Harrah Coll...
# 41    Abubakar, A.M., Department of Economics and Bu...
# 43    Nydahl, P., Nursing Research, University Hospi...
# ...                                                 ...
# 998   Hin, C.W., College of Business, Universiti of ...
# 1015  Sokol, T., KU Leuven, Institute for Social Law...
# 1023  McHale, J., School of Law, University of Birmi...
# 1034  Lang, I.G., London School of Economics and Pol...
# 1043  Offermanns, G., Alpen-Adria-Universität Klagen...
#
#                           Publisher  \
# 15                     Elsevier Ltd
# 24                     Elsevier Ltd
# 36                     Elsevier Ltd
# 41                     Elsevier Ltd
# 43        American Thoracic Society
# ...                             ...
# 998                Medwell Journals
# 1015           University of Zagreb
# 1023              MA Healthcare Ltd
# 1034            Yozmot Heiliger Ltd
# 1043  Urban und Fischer Verlag Jena
#
#                                              References  \
# 15    (2010), AMI (African Medical Investments). AMI...
# 24    Health Tourism (2004), http://www.hospitals-ma...
# 36    Baloglu, S., Pekcan, Y.A., The website design ...
# 41    Abubakar, A.M., Ilkan, M., More adverts or mor...
# 43    Brower, R.G., Consequences of bed rest (2009) ...
# ...                                                 ...
# 998   SARS: Economic impacts and implications (2003)...
# 1015  Note; Note; Marhold, F., Modernisation of Euro...
# 1023  (2008) Proposal for A Directive of the Europea...
# 1034  see e.g. Case C-76/90 (1991) Säger, pp. ECR1-4...
# 1043  Bertinato, L., (2005) Cross-Border Health Care...
#
#                                  Correspondence Address      ISSN  \
# 15    Glinos, I.A.; Department of Health Organisatio...  13538292
# 24    García-Altés, A.; Fund. Inst. de Invest./Serv....  01607383
# 36    Cormany, D.; University of Nevada, Harrah Coll...  02615177
# 41    Abubakar, A.M.; Department of Economics and Bu...  2212571X
# 43    Nydahl, P.; Nursing Research, University Hospi...  23256621
# ...                                                 ...       ...
# 998   Hin, C.W.; College of Business, Universiti of ...  19935250
# 1015  Sokol, T.; KU Leuven, Institute for Social Law...  18455662
# 1023  McHale, J.; School of Law, University of Birmi...  09660461
# 1034  Lang, I. G.; London School of Economics and Po...  07231393
# 1043  Offermanns, G.; Alpen-Adria-Universität Klagen...  09445587
#
#      Language of Original Document Document Type Publication Stage  Source  \
# 15                         English       Article             Final  Scopus
# 24                         English       Article             Final  Scopus
# 36                         English       Article             Final  Scopus
# 41                         English       Article             Final  Scopus
# 43                         English        Review             Final  Scopus
# ...                            ...           ...               ...     ...
# 998                        English       Article             Final  Scopus
# 1015                       English       Article             Final  Scopus
# 1023                       English       Article             Final  Scopus
# 1034                       English       Article             Final  Scopus
# 1043                        German       Article             Final  Scopus
#
#                      EID
# 15    2-s2.0-77957654236
# 24    2-s2.0-14544304577
# 36    2-s2.0-79953879112
# 41    2-s2.0-84953431868
# 43    2-s2.0-85018977607
# ...                  ...
# 998   2-s2.0-84897414268
# 1015  2-s2.0-84871704271
# 1023  2-s2.0-77956203276
# 1034  2-s2.0-74849108222
# 1043  2-s2.0-47149108517
#
# [378 rows x 17 columns]

# %%
df.keys()
# Out:
# Index(['Authors', 'Title', 'Year', 'Issue', 'Volume', 'Cited by',
#        'Affiliations', 'Authors with affiliations', 'Publisher', 'References',
#        'Correspondence Address', 'ISSN', 'Language of Original Document',
#        'Document Type', 'Publication Stage', 'Source', 'EID'],
#       dtype='object')

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# Remove rows with null values
df.dropna(inplace=True)

# Reset the index
df.reset_index(drop=True, inplace=True)

# Save the cleaned dataset to a new file
df.to_csv('cleaned.csv', index=False)
# Out:
# <ipython-input-9-fd07210e3772>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
# <ipython-input-9-fd07210e3772>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#                                                Authors  \
# 0         Glinos I.A., Baeten R., Helble M., Maarse H.
# 1                                      García-Altés A.
# 2                               Cormany D., Baloglu S.
# 3                              Abubakar A.M., Ilkan M.
# 4    Nydahl P., Sricharoenchai T., Chandra S., Kund...
# ..                                                 ...
# 373                     Hin C.W., Bohari A.M., Pu L.T.
# 374                 Sokol T., Hodak L.M., Abramović A.
# 375                                          McHale J.
# 376                                          Lang I.G.
# 377                                      Offermanns G.
#
#                                                  Title  Year Issue Volume  \
# 0          A typology of cross-border patient mobility  2010     6     16
# 1           The development of health tourism services  2005     1     32
# 2    Medical travel facilitator websites: An explor...  2011     4     32
# 3    Impact of online WOM on destination trust and ...  2016     3      5
# 4    Safety of patient mobilization and rehabilitat...  2017     5     14
# ..                                                 ...   ...   ...    ...
# 373  An analysis of competitiveness of medical tour...  2013     6      7
# 374  Patient mobility directive: One step forward o...  2012  2012      8
# 375   Health tourism and the UK: Some new developments  2010    14     19
# 376  Patient mobility in the European Union: pushin...  2009     4     28
# 377  Patient mobility in Europe [Patientenmobilität...  2007    56     15
#
#      Cited by                                       Affiliations  \
# 0       119.0  Department of Health Organisation, Policy and ...
# 1       101.0  Fund. Inst. de Invest./Serv. Salud, Pere Seraf...
# 2        79.0  University of Nevada, Harrah College of Hotel ...
# 3        74.0  Department of Economics and Business Administr...
# 4        71.0  Nursing Research, University Hospital of Schle...
# ..        ...                                                ...
# 373       1.0  College of Business, Universiti of Utara Malay...
# 374       1.0  KU Leuven, Institute for Social Law, Belgium; ...
# 375       1.0  School of Law, University of Birmingham, Unite...
# 376       1.0  London School of Economics and Political Scien...
# 377       1.0  Alpen-Adria-Universität Klagenfurt, Fakultät f...
#
#                              Authors with affiliations  \
# 0    Glinos, I.A., Department of Health Organisatio...
# 1    García-Altés, A., Fund. Inst. de Invest./Serv....
# 2    Cormany, D., University of Nevada, Harrah Coll...
# 3    Abubakar, A.M., Department of Economics and Bu...
# 4    Nydahl, P., Nursing Research, University Hospi...
# ..                                                 ...
# 373  Hin, C.W., College of Business, Universiti of ...
# 374  Sokol, T., KU Leuven, Institute for Social Law...
# 375  McHale, J., School of Law, University of Birmi...
# 376  Lang, I.G., London School of Economics and Pol...
# 377  Offermanns, G., Alpen-Adria-Universität Klagen...
#
#                          Publisher  \
# 0                     Elsevier Ltd
# 1                     Elsevier Ltd
# 2                     Elsevier Ltd
# 3                     Elsevier Ltd
# 4        American Thoracic Society
# ..                             ...
# 373               Medwell Journals
# 374           University of Zagreb
# 375              MA Healthcare Ltd
# 376            Yozmot Heiliger Ltd
# 377  Urban und Fischer Verlag Jena
#
#                                             References  \
# 0    (2010), AMI (African Medical Investments). AMI...
# 1    Health Tourism (2004), http://www.hospitals-ma...
# 2    Baloglu, S., Pekcan, Y.A., The website design ...
# 3    Abubakar, A.M., Ilkan, M., More adverts or mor...
# 4    Brower, R.G., Consequences of bed rest (2009) ...
# ..                                                 ...
# 373  SARS: Economic impacts and implications (2003)...
# 374  Note; Note; Marhold, F., Modernisation of Euro...
# 375  (2008) Proposal for A Directive of the Europea...
# 376  see e.g. Case C-76/90 (1991) Säger, pp. ECR1-4...
# 377  Bertinato, L., (2005) Cross-Border Health Care...
#
#                                 Correspondence Address      ISSN  \
# 0    Glinos, I.A.; Department of Health Organisatio...  13538292
# 1    García-Altés, A.; Fund. Inst. de Invest./Serv....  01607383
# 2    Cormany, D.; University of Nevada, Harrah Coll...  02615177
# 3    Abubakar, A.M.; Department of Economics and Bu...  2212571X
# 4    Nydahl, P.; Nursing Research, University Hospi...  23256621
# ..                                                 ...       ...
# 373  Hin, C.W.; College of Business, Universiti of ...  19935250
# 374  Sokol, T.; KU Leuven, Institute for Social Law...  18455662
# 375  McHale, J.; School of Law, University of Birmi...  09660461
# 376  Lang, I. G.; London School of Economics and Po...  07231393
# 377  Offermanns, G.; Alpen-Adria-Universität Klagen...  09445587
#
#     Language of Original Document Document Type Publication Stage  Source  \
# 0                         English       Article             Final  Scopus
# 1                         English       Article             Final  Scopus
# 2                         English       Article             Final  Scopus
# 3                         English       Article             Final  Scopus
# 4                         English        Review             Final  Scopus
# ..                            ...           ...               ...     ...
# 373                       English       Article             Final  Scopus
# 374                       English       Article             Final  Scopus
# 375                       English       Article             Final  Scopus
# 376                       English       Article             Final  Scopus
# 377                        German       Article             Final  Scopus
#
#                     EID
# 0    2-s2.0-77957654236
# 1    2-s2.0-14544304577
# 2    2-s2.0-79953879112
# 3    2-s2.0-84953431868
# 4    2-s2.0-85018977607
# ..                  ...
# 373  2-s2.0-84897414268
# 374  2-s2.0-84871704271
# 375  2-s2.0-77956203276
# 376  2-s2.0-74849108222
# 377  2-s2.0-47149108517
#
# [378 rows x 17 columns]

# %%
# Extract relevant columns for bibliographic connections
df_citations = df[['Publisher', 'Cited by']]

unique_nodes = set(df['Publisher']).union(set(df['Cited by']))
print(unique_nodes)

# Create an empty directed graph
graph = nx.DiGraph()
# Out:
# {"Teoriya i Praktika Fizicheskoi Kul'tury", 1.0, 2.0, 3.0, 'Il Pensiero Scientifico Editore s.r.l.', 'Journal of Chemical and Pharmaceutical Research', 4.0, 5.0, 6.0, 'Elsevier Inc.', 7.0, 8.0, 9.0, 'Cambridge University Press', 10.0, 11.0, 12.0, 13.0, 'SAGE Publications Ltd', 'Palgrave Macmillan Ltd.', 'Global Research Online', 14.0, 'Medicinska Naklada Zagreb', 'Economics Bulletin', 15.0, 'Yozmot Heiliger Ltd', 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 'Cracow University of Economics', 'Taylor and Francis Ltd.', 27.0, 28.0, 30.0, 31.0, 32.0, 35.0, 38.0, 41.0, 44.0, 45.0, 'American Association of Critical Care Nurses', 47.0, 'Institute for Tourism', 51.0, 52.0, 'Joint Commission Resources, Inc.', 'Hindawi Limited', 'Korean Cancer Association', 'American Scientific Publishers', 71.0, 'American Thoracic Society', 'Ascend Media', 74.0, 79.0, 'Blackwell Publishing Ltd', 16.0, 'Blackwell Publishing Inc.', 'Maney Publishing', 'Emerald Group Publishing Ltd.', 101.0, 'M.E. Sharpe Inc.', 'Centers for Disease Control and Prevention (CDC)', 'Universidad del Zulia', 'Churchill Livingstone', 'Pharmainfo Publications', 119.0, 'Cognizant Communication Corporation', 'Canadian Medical Association', 25.0, 'Cogent OA', 'Urban und Fischer Verlag Jena', 26.0, 'Alpha Publishers', 'International Multidisciplinary Scientific Geoconference', 'Inderscience Enterprises Ltd.', 'Springer-Verlag Italia s.r.l.', 'ASTM International', 'Frontiers Research Foundation', 'Mosby Inc.', 'Research Journal of Pharmaceutical, Biological and Chemical Sciences', 'Association of Pharmaceutical Teachers of India', 'World Health Organization', 'BioMed Central Ltd.', 'Springer New York LLC', 'Indiana University Press', 'Tehran University of Medical Sciences', 'Editura Universitatii din Oradea', 'University of Bucharest', 'Growing Science', 'Baqiyatallah University of Medical Sciences', 'Taylor and Francis Ltd', 'Fundacion Educacion Medica', 'MA Healthcare Ltd', 'Royal Australian College of General Practitioners', 'Sociologicky Ustav', 'Asian Network for Scientific Information', 'Reasearch Centre for Astronomy and Earth Sciences Hungarian Academy', 'Makerere University, Medical School', 'Nomos Verlagsgesellschaft mbH und Co', 'John Wiley and Sons Ltd', 'Iranian Journal of Public Health', 'NTC Publications Ltd.', 'Africa Journals', 'Universiti Putra Malaysia', 'SpringerOpen', 'Oxford University Press', 'Inderscience Publishers', 'Kluwer Academic Publishers', 'Universiti Malaysia Sarawak', 'Editura Cefin', 'Entrepreneurship and Sustainability Center', 'University of Zagreb', 'International Information Institute Ltd.', 'SAGE Publications Inc.', 'Nicolaus Copenicus University Press', 'IJESE', 'University of London', 'ExcelingTech', 'Page Press Publications', 'Anatolia', 'Edinburgh University Press', 'Klinicka Bolnica Sestre Milosrdnice', 'MDPI AG', 'Elsevier', 'W.B. Saunders', 'Kerman University of Medical Sciences', 'Kritika Kultura', 'Zhengzhou University', 'BMJ Publishing Group', 'Science and Engineering Research Support Society', 'Kamla-Raj Enterprises', 'Taylor and Francis Inc.', 'Nature Publishing Group', 'Elsevier Ireland Ltd', 'Sultan Qaboos University', 'Wiley-Liss Inc.', 'American Society for Microbiology', 'Sharif University of Technology', 'Canadian Center of Science and Education', 'AlphaMed Press', 'Academic Publishing House Researcher', 'Journal of Medical Internet Research', 'University of the West Indies', 'Co-Action Publishing', 'Mediterranean Center of Social and Educational Research', 'Corporacion Universitaria Lasallista', 'Mary Ann Liebert Inc.', 'Korea Distribution Science Association (KODISA)', 'Routledge', 'European Centre for Disease Prevention and Control (ECDC)', 'Scibulcom Ltd.', 'De Gruyter Open Ltd', 'Department of Health and Human Services', 'Lexis Publisher', 'Springer Netherlands', 'Lippincott Williams and Wilkins', 'Indian Journal of Public Health Research and Development', 'Elsevier Ltd', 'Springer Verlag', 'Equinox Publishing Ltd', 'E ...

# %%
# Add nodes to the graph
for _, row in df_citations.iterrows():
    paper_title = row['Publisher']
    citation = row['Cited by']

    # Add paper title as a node
    graph.add_node(paper_title)

    # Add citation as a node
    graph.add_node(citation)

    # Add edge between paper title and citation
    graph.add_edge(paper_title, citation)

# Visualize the graph
pos = nx.spring_layout(graph)
plt.figure(figsize=(12, 8))
nx.draw_networkx(graph, pos, with_labels=True, node_size=200, font_size=10, edge_color='gray')
plt.title('22MCB0002 Bibliographic Subgraph')
plt.axis('off')
plt.show()

# %% [markdown]
# B) Node and edge classification
#    Number of topics or papers (similarity in biblographic graph like topic modeling) using clustering(preferable)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import KMeans
# Extract node features (number of topics or papers)
node_features = np.array([len(graph[node]) for node in graph.nodes()]).reshape(-1, 1)

# Remove rows with NaN or null values
df.dropna(inplace=True)

# Select relevant features for clustering (e.g., abstracts)
data = df['Title'].tolist()

# Vectorize the abstracts using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(data)

# Reduce dimensionality using Truncated SVD
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X)

# Apply K-means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
labels = kmeans.fit_predict(X_svd)

# Plot the clusters
plt.figure(figsize=(8, 5))
plt.scatter(X_svd[:, 0], X_svd[:, 1], c=labels, cmap='viridis')
plt.title('22MCB0002 Clustering of Medical Journal Papers')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()
# Out:
# <ipython-input-13-2ccb1c72a325>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the columns you want to evaluate health on
columns_to_evaluate = ['Title', 'Issue', 'Year']

fig, axes = plt.subplots(1, len(columns_to_evaluate), figsize=(8, 5))
axes = axes.flatten()

for i, col in enumerate(columns_to_evaluate):
    g = sns.countplot(x=col, data=df, ax=axes[i])
    if len(df[col].unique()) > 5:
        g.set_xticks(range(0, len(df[col].unique()), 5))
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')

plt.suptitle('22MCB0002 Distribution of Variables', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-3b0055562e37>:18: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
